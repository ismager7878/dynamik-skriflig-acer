# %%
# Add parent directory to path so we can import scripts module
import sys
import os

# Get the workspace root (parent of 'Eksamens notebooks')
notebook_dir = os.path.dirname(os.path.abspath("__file__"))
workspace_root = os.path.dirname(notebook_dir)

if workspace_root not in sys.path:
    sys.path.insert(0, workspace_root)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy import pprint

# %% [markdown]
# ## Opg 1
#
# #### 1)
#
# Find the jacobian matrix for the functions
#
# Using the formula:
#
# $$
# J = \begin{bmatrix}
# \frac{\partial f_1}{\partial x_1} & \frac{\partial f_1}{\partial x_2} \\
# \frac{\partial f_2}{\partial x_1} & \frac{\partial f_2}{\partial x_2}
# \end{bmatrix}
# $$
# **NOTE** Husk den rigtig rækkefølge af variablerne.

# %%
theta, s = sp.symbols('theta s')

def jacobian_mat(functions, vars):
    J = sp.Matrix([[sp.diff(f, var) for var in vars] for f in functions])
    return J


fs = [s + 4*sp.cos(theta), 3 + 4*sp.sin(theta)]
vars = [s, theta]


J = jacobian_mat(fs, vars)
print("Jacobian matrix:")
sp.pprint(J)
# Out:
# Jacobian matrix:
# ⎡1  -4⋅sin(θ)⎤
# ⎢            ⎥
# ⎣0  4⋅cos(θ) ⎦

# %% [markdown]
# #### 2)
# To find the singularitets, find where the determinant of the Jacobian is equal to zero.

# %%
det_J = J.det()
print("\nDeterminant of the Jacobian:")
pprint(det_J)
sings = sp.solve(det_J, (s, theta))
print("Singularities(Rads):")
pprint(sings)
sings_deg = [(s_val, np.degrees(float(theta_val))) for s_val, theta_val in sings]
print("Singularities(Degree):")
pprint(sings_deg)
# Out:
# Determinant of the Jacobian:
# 4⋅cos(θ)
# Singularities(Rads):
# ⎡⎛   π⎞  ⎛   3⋅π⎞⎤
# ⎢⎜s, ─⎟, ⎜s, ───⎟⎥
# ⎣⎝   2⎠  ⎝    2 ⎠⎦
# Singularities(Degree):
# [(s, 90.0), (s, 270.0)]

# %% [markdown]
# #### 3)
# Visualize the singularities

# %%
plt.figure()

# Select values to get an idea of trajectories
theta_vals = np.array([0, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
s_vales = [1,2,3,4]

# Visualize the trajectories
x_vals = []
y_vals = []

sing_x_vals = []
sing_y_vals = []

for s_vals in s_vales:
    for theta_val in theta_vals:
        x_vals.append(float(fs[0].subs({s: s_vals, theta: theta_val}).evalf()))
        y_vals.append(float(fs[1].subs({s: s_vals, theta: theta_val}).evalf()))

    for s_sing, theta_sing in sings:
        sing_x_vals.append(float(fs[0].subs({s: s_vals, theta: theta_sing}).evalf()))
        sing_y_vals.append(float(fs[1].subs({s: s_vals, theta: theta_sing}).evalf()))



plt.plot(x_vals, y_vals, 'o-')
plt.plot(sing_x_vals, sing_y_vals, 'rx', markersize=10, label='Singularities')
plt.legend()
plt.title('Trajectories with Singularities')
plt.xlabel('f1 (x)')
plt.ylabel('f2 (y)')
plt.grid()
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')
plt.show()
